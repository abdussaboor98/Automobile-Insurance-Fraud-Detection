# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
)
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from skopt import gp_minimize
from collections import Counter

# %%
# Load data
df = pd.read_csv(
    "../../data/Angoss Knowledge Seeker - carclaims.txt/carclaims_original.csv"
)
# Drop row with missing data
df.drop(df[df["DayOfWeekClaimed"] == "0"].index, inplace=True)
# Drop ID column
df.drop(columns="PolicyNumber", inplace=True)
df.drop(columns="Age", inplace=True)

# Train-test split
carclaims_train, carclaims_test = train_test_split(df, test_size=0.2, random_state=141)

# %%
space = [
    Integer(64, 1024, name="rf_n_estimators"),
    Categorical(["gini", "entropy", "log_loss"], name="rf_criterion"),
    Integer(5, 100, name="rf_max_depth"),
    Integer(2, 30, name="rf_min_samples_split"),
    Integer(1, 30, name="rf_min_samples_leaf"),
]

@use_named_args(space)
def train_and_predict(
    rf_n_estimators,
    rf_criterion,
    rf_max_depth,
    rf_min_samples_split,
    rf_min_samples_leaf,
):
    
    print(f'Running: rf_n_estimators {rf_n_estimators}, rf_criterion {rf_criterion}, rf_max_depth {rf_max_depth}, rf_min_samples_split {rf_min_samples_split}, rf_min_samples_leaf {rf_min_samples_leaf},')
   
    # X y split
    X_train = carclaims_train.drop('FraudFound', axis=1)
    y_train = carclaims_train['FraudFound']

    X_test = carclaims_test.drop('FraudFound', axis=1)
    y_test = carclaims_test['FraudFound']

    # Encode target variable
    y_train = y_train.map({'Yes': 1, 'No': 0})
    y_test = y_test.map({'Yes': 1, 'No': 0})

    y_train = y_train.astype(int)
    y_test = y_test.astype(int)

    # Lebel Encode features
    column_labels = {
        'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        'DayOfWeek': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
        'DayOfWeekClaimed': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
        'MonthClaimed': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        'AgeOfPolicyHolder': ['16 to 17', '18 to 20', '21 to 25', '26 to 30', '31 to 35', '36 to 40', '41 to 50', '51 to 65', 'over 65'],
        'NumberOfSuppliments': ['none', '1 to 2', '3 to 5', 'more than 5'],
        'AddressChange-Claim': ['no change', 'under 6 months', '1 year', '2 to 3 years', '4 to 8 years'],
        'NumberOfCars': ['1 vehicle', '2 vehicles', '3 to 4', '5 to 8', 'more than 8'],
        'VehiclePrice': ['less than 20,000', '20,000 to 29,000', '30,000 to 39,000', '40,000 to 59,000', '60,000 to 69,000', 'more than 69,000'],
        'Days:Policy-Accident': ['none', '1 to 7', '15 to 30', '8 to 15', 'more than 30'],
        'Days:Policy-Claim': ['15 to 30', '8 to 15', 'more than 30'],
        'PastNumberOfClaims': ['none', '1', '2 to 4', 'more than 4'],
        'AgeOfVehicle': ['new', '2 years', '3 years', '4 years', '5 years', '6 years', '7 years', 'more than 7'],
        'Make': ['Accura', 'BMW', 'Chevrolet', 'Dodge', 'Ferrari', 'Ford', 'Honda', 'Jaguar', 'Lexus', 'Mazda', 'Mecedes', 'Mercury', 'Nisson', 'Pontiac', 'Porche', 'Saab', 'Saturn', 'Toyota', 'VW']
    
        }

    for column, labels in column_labels.items():
        oe = OrdinalEncoder(categories=[labels], handle_unknown='error')
        X_train[column] = oe.fit_transform(X_train[[column]])
        X_test[column] = oe.transform(X_test[[column]])

    # one hot encode
    columns_one_hot = {
        'AccidentArea': ['Rural', 'Urban'],
        'Sex': ['Female', 'Male'],
        'MaritalStatus': ['Divorced', 'Married', 'Single', 'Widow'],
        'PoliceReportFiled': ['No', 'Yes'],
        'WitnessPresent': ['No', 'Yes'],
        'AgentType': ['External', 'Internal'],
        'BasePolicy': ['All Perils', 'Collision', 'Liability'],
        'Fault': ['Policy Holder', 'Third Party'],
        'PolicyType': ['Sedan - All Perils', 'Sedan - Collision', 'Sedan - Liability','Sport - All Perils', 'Sport - Collision', 'Sport - Liability', 'Utility - All Perils', 'Utility - Collision', 'Utility - Liability'],
        'VehicleCategory': ['Sedan', 'Sport', 'Utility'],
        
    }

    for column, labels in columns_one_hot.items():
        ohe = OneHotEncoder(sparse_output=False, categories=[labels], drop='first', handle_unknown='error')
        encoded_nominal = ohe.fit_transform(X_train[[column]])
        X_train = pd.concat([X_train, pd.DataFrame(encoded_nominal, columns=ohe.get_feature_names_out([column]), index=X_train.index)], axis=1)

        encoded_nominal = ohe.transform(X_test[[column]])
        X_test = pd.concat([X_test, pd.DataFrame(encoded_nominal, columns=ohe.get_feature_names_out([column]), index=X_test.index)], axis=1)

    X_test.drop(columns=columns_one_hot.keys(), axis=1, inplace=True)
    X_train.drop(columns=columns_one_hot.keys(), axis=1, inplace=True)
    
    print('Original dataset shape %s' % Counter(y_train))    
    sm = SMOTE(random_state=42)
    X_train_balanced, y_train_balanced = sm.fit_resample(X_train, y_train)
    print('Balanced dataset shape %s' % Counter(y_train_balanced))

    rf_classifier = RandomForestClassifier(
        n_estimators=rf_n_estimators,
        criterion=rf_criterion,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        random_state=141,
    )
    rf_classifier.fit(X_train_balanced, y_train_balanced)

    y_pred = rf_classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.4f} Precision: {precision:.4f} Recall: {recall:.4f} F1 Score: {f1:.4f}")
    return -f1
    
res_gp = gp_minimize(train_and_predict, space, n_calls=100, random_state=141)

print(f'Best f1: {res_gp.fun}')
print(f'Best params: {res_gp.x}')
# Out:
# Running: rf_n_estimators 406, rf_criterion gini, rf_max_depth 52, rf_min_samples_split 26, rf_min_samples_leaf 17,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9270 Precision: 0.2297 Recall: 0.0919 F1 Score: 0.1313
# Running: rf_n_estimators 830, rf_criterion entropy, rf_max_depth 85, rf_min_samples_split 26, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9300 Precision: 0.2687 Recall: 0.0973 F1 Score: 0.1429
# Running: rf_n_estimators 904, rf_criterion entropy, rf_max_depth 93, rf_min_samples_split 12, rf_min_samples_leaf 13,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9316 Precision: 0.2045 Recall: 0.0486 F1 Score: 0.0786
# Running: rf_n_estimators 763, rf_criterion gini, rf_max_depth 75, rf_min_samples_split 10, rf_min_samples_leaf 14,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9296 Precision: 0.2576 Recall: 0.0919 F1 Score: 0.1355
# Running: rf_n_estimators 375, rf_criterion gini, rf_max_depth 82, rf_min_samples_split 6, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9309 Precision: 0.2667 Recall: 0.0865 F1 Score: 0.1306
# Running: rf_n_estimators 350, rf_criterion entropy, rf_max_depth 57, rf_min_samples_split 23, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9293 Precision: 0.2537 Recall: 0.0919 F1 Score: 0.1349
# Running: rf_n_estimators 173, rf_criterion entropy, rf_max_depth 84, rf_min_samples_split 19, rf_min_samples_leaf 7,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9339 Precision: 0.2432 Recall: 0.0486 F1 Score: 0.0811
# Running: rf_n_estimators 489, rf_criterion gini, rf_max_depth 39, rf_min_samples_split 23, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9277 Precision: 0.2432 Recall: 0.0973 F1 Score: 0.1390
# Running: rf_n_estimators 172, rf_criterion entropy, rf_max_depth 80, rf_min_samples_split 14, rf_min_samples_leaf 7,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9342 Precision: 0.2188 Recall: 0.0378 F1 Score: 0.0645
# Running: rf_n_estimators 293, rf_criterion gini, rf_max_depth 37, rf_min_samples_split 18, rf_min_samples_leaf 28,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9209 Precision: 0.2435 Recall: 0.1514 F1 Score: 0.1867
# Running: rf_n_estimators 196, rf_criterion gini, rf_max_depth 28, rf_min_samples_split 14, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.2344 Recall: 0.1622 F1 Score: 0.1917
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 32, rf_min_samples_split 16, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9206 Precision: 0.2619 Recall: 0.1784 F1 Score: 0.2122
# Running: rf_n_estimators 221, rf_criterion log_loss, rf_max_depth 32, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9267 Precision: 0.2697 Recall: 0.1297 F1 Score: 0.1752
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7776 Precision: 0.1506 Recall: 0.5838 F1 Score: 0.2395
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 100, rf_min_samples_split 12, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9206 Precision: 0.2619 Recall: 0.1784 F1 Score: 0.2122
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 100, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9199 Precision: 0.2459 Recall: 0.1622 F1 Score: 0.1954
# Running: rf_n_estimators 774, rf_criterion entropy, rf_max_depth 83, rf_min_samples_split 3, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9251 Precision: 0.2553 Recall: 0.1297 F1 Score: 0.1720
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 100, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9199 Precision: 0.2459 Recall: 0.1622 F1 Score: 0.1954
# Running: rf_n_estimators 991, rf_criterion entropy, rf_max_depth 98, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9261 Precision: 0.2637 Recall: 0.1297 F1 Score: 0.1739
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 25, rf_min_samples_leaf 27,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7798 Precision: 0.1521 Recall: 0.5838 F1 Score: 0.2413
# Running: rf_n_estimators 1024, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 28,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7727 Precision: 0.1485 Recall: 0.5892 F1 Score: 0.2372
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 26,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7802 Precision: 0.1523 Recall: 0.5838 F1 Score: 0.2416
# Running: rf_n_estimators 965, rf_criterion log_loss, rf_max_depth 5, rf_min_samples_split 15, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7682 Precision: 0.1457 Recall: 0.5892 F1 Score: 0.2337
# Running: rf_n_estimators 178, rf_criterion log_loss, rf_max_depth 100, rf_min_samples_split 17, rf_min_samples_leaf 5,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9335 Precision: 0.2222 Recall: 0.0432 F1 Score: 0.0724
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7776 Precision: 0.1554 Recall: 0.6108 F1 Score: 0.2478
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 11, rf_min_samples_split 30, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9030 Precision: 0.2432 Recall: 0.2919 F1 Score: 0.2654
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 16, rf_min_samples_split 11, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9296 Precision: 0.2333 Recall: 0.0757 F1 Score: 0.1143
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7763 Precision: 0.1469 Recall: 0.5676 F1 Score: 0.2333
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 8,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7733 Precision: 0.1508 Recall: 0.6000 F1 Score: 0.2410
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 17,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8875 Precision: 0.2188 Recall: 0.3405 F1 Score: 0.2664
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 12, rf_min_samples_split 27, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9040 Precision: 0.2419 Recall: 0.2811 F1 Score: 0.2600
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 25, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8862 Precision: 0.2215 Recall: 0.3568 F1 Score: 0.2733
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 2, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8813 Precision: 0.2033 Recall: 0.3351 F1 Score: 0.2531
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 12, rf_min_samples_split 22, rf_min_samples_leaf 14,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9089 Precision: 0.2303 Recall: 0.2216 F1 Score: 0.2259
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7750 Precision: 0.1470 Recall: 0.5730 F1 Score: 0.2340
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 11, rf_min_samples_split 24, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8943 Precision: 0.2235 Recall: 0.3081 F1 Score: 0.2591
# Running: rf_n_estimators 598, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 29, rf_min_samples_leaf 8,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8862 Precision: 0.2252 Recall: 0.3676 F1 Score: 0.2793
# Running: rf_n_estimators 64, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 4,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8865 Precision: 0.2241 Recall: 0.3622 F1 Score: 0.2769
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 67, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9199 Precision: 0.2459 Recall: 0.1622 F1 Score: 0.1954
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 65, rf_min_samples_split 2, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9377 Precision: 0.3478 Recall: 0.0432 F1 Score: 0.0769
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8797 Precision: 0.2165 Recall: 0.3838 F1 Score: 0.2768
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8797 Precision: 0.2165 Recall: 0.3838 F1 Score: 0.2768
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 30, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8573 Precision: 0.1883 Recall: 0.4162 F1 Score: 0.2593
# Running: rf_n_estimators 64, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 27, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8800 Precision: 0.2026 Recall: 0.3405 F1 Score: 0.2540
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8836 Precision: 0.2041 Recall: 0.3243 F1 Score: 0.2505
# Running: rf_n_estimators 931, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 5,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8833 Precision: 0.2093 Recall: 0.3405 F1 Score: 0.2593
# Running: rf_n_estimators 1019, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 4,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7704 Precision: 0.1461 Recall: 0.5838 F1 Score: 0.2338
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8923 Precision: 0.2162 Recall: 0.3027 F1 Score: 0.2523
# Running: rf_n_estimators 64, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 29, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8836 Precision: 0.2157 Recall: 0.3568 F1 Score: 0.2688
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 28, rf_min_samples_leaf 5,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8833 Precision: 0.2074 Recall: 0.3351 F1 Score: 0.2562
# Running: rf_n_estimators 697, rf_criterion entropy, rf_max_depth 46, rf_min_samples_split 14, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9254 Precision: 0.2581 Recall: 0.1297 F1 Score: 0.1727
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8804 Precision: 0.2160 Recall: 0.3784 F1 Score: 0.2750
# Running: rf_n_estimators 558, rf_criterion gini, rf_max_depth 31, rf_min_samples_split 22, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9355 Precision: 0.2812 Recall: 0.0486 F1 Score: 0.0829
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 30, rf_min_samples_leaf 22,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8625 Precision: 0.1928 Recall: 0.4054 F1 Score: 0.2613
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 29, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8797 Precision: 0.2165 Recall: 0.3838 F1 Score: 0.2768
# Running: rf_n_estimators 118, rf_criterion gini, rf_max_depth 89, rf_min_samples_split 23, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9163 Precision: 0.2256 Recall: 0.1622 F1 Score: 0.1887
# Running: rf_n_estimators 403, rf_criterion gini, rf_max_depth 58, rf_min_samples_split 13, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9196 Precision: 0.2439 Recall: 0.1622 F1 Score: 0.1948
# Running: rf_n_estimators 387, rf_criterion gini, rf_max_depth 74, rf_min_samples_split 22, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9196 Precision: 0.2480 Recall: 0.1676 F1 Score: 0.2000
# Running: rf_n_estimators 134, rf_criterion gini, rf_max_depth 17, rf_min_samples_split 15, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9157 Precision: 0.2449 Recall: 0.1946 F1 Score: 0.2169
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8907 Precision: 0.2286 Recall: 0.3459 F1 Score: 0.2753
# Running: rf_n_estimators 955, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 25, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8612 Precision: 0.1908 Recall: 0.4054 F1 Score: 0.2595
# Running: rf_n_estimators 1016, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 4, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8632 Precision: 0.1922 Recall: 0.4000 F1 Score: 0.2596
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8927 Precision: 0.2276 Recall: 0.3297 F1 Score: 0.2693
# Running: rf_n_estimators 127, rf_criterion gini, rf_max_depth 11, rf_min_samples_split 14, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8956 Precision: 0.2249 Recall: 0.3027 F1 Score: 0.2581
# Running: rf_n_estimators 302, rf_criterion log_loss, rf_max_depth 46, rf_min_samples_split 10, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9377 Precision: 0.3158 Recall: 0.0324 F1 Score: 0.0588
# Running: rf_n_estimators 232, rf_criterion log_loss, rf_max_depth 8, rf_min_samples_split 13, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8580 Precision: 0.1892 Recall: 0.4162 F1 Score: 0.2601
# Running: rf_n_estimators 71, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 5, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8589 Precision: 0.1875 Recall: 0.4054 F1 Score: 0.2564
# Running: rf_n_estimators 80, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 9, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8787 Precision: 0.2038 Recall: 0.3514 F1 Score: 0.2579
# Running: rf_n_estimators 868, rf_criterion log_loss, rf_max_depth 53, rf_min_samples_split 5, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9251 Precision: 0.2553 Recall: 0.1297 F1 Score: 0.1720
# Running: rf_n_estimators 126, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 24, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8859 Precision: 0.2189 Recall: 0.3514 F1 Score: 0.2697
# Running: rf_n_estimators 570, rf_criterion entropy, rf_max_depth 64, rf_min_samples_split 27, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9264 Precision: 0.2667 Recall: 0.1297 F1 Score: 0.1745
# Running: rf_n_estimators 1003, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 5, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8911 Precision: 0.2294 Recall: 0.3459 F1 Score: 0.2759
# Running: rf_n_estimators 895, rf_criterion entropy, rf_max_depth 13, rf_min_samples_split 20, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9092 Precision: 0.2487 Recall: 0.2541 F1 Score: 0.2513
# Running: rf_n_estimators 1006, rf_criterion entropy, rf_max_depth 22, rf_min_samples_split 23, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9248 Precision: 0.2526 Recall: 0.1297 F1 Score: 0.1714
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 12, rf_min_samples_split 3, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9053 Precision: 0.2415 Recall: 0.2703 F1 Score: 0.2551
# Running: rf_n_estimators 149, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 2, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8606 Precision: 0.1945 Recall: 0.4216 F1 Score: 0.2662
# Running: rf_n_estimators 684, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 26, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8842 Precision: 0.2133 Recall: 0.3459 F1 Score: 0.2639
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 13, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8797 Precision: 0.2165 Recall: 0.3838 F1 Score: 0.2768
# Running: rf_n_estimators 737, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 17, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8615 Precision: 0.1929 Recall: 0.4108 F1 Score: 0.2625
# Running: rf_n_estimators 844, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 2, rf_min_samples_leaf 8,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8846 Precision: 0.2178 Recall: 0.3568 F1 Score: 0.2705
# Running: rf_n_estimators 864, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 27, rf_min_samples_leaf 9,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8632 Precision: 0.1890 Recall: 0.3892 F1 Score: 0.2544
# Running: rf_n_estimators 773, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8791 Precision: 0.2134 Recall: 0.3784 F1 Score: 0.2729
# Running: rf_n_estimators 960, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 4, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8641 Precision: 0.1905 Recall: 0.3892 F1 Score: 0.2558
# Running: rf_n_estimators 886, rf_criterion gini, rf_max_depth 79, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9199 Precision: 0.2500 Recall: 0.1676 F1 Score: 0.2006
# Running: rf_n_estimators 686, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 14, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8781 Precision: 0.2097 Recall: 0.3730 F1 Score: 0.2685
# Running: rf_n_estimators 496, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8794 Precision: 0.2141 Recall: 0.3784 F1 Score: 0.2734
# Running: rf_n_estimators 947, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 6, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8816 Precision: 0.2152 Recall: 0.3676 F1 Score: 0.2715
# Running: rf_n_estimators 925, rf_criterion log_loss, rf_max_depth 9, rf_min_samples_split 18, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8784 Precision: 0.2104 Recall: 0.3730 F1 Score: 0.2690
# Running: rf_n_estimators 128, rf_criterion log_loss, rf_max_depth 8, rf_min_samples_split 3, rf_min_samples_leaf 19,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8602 Precision: 0.1894 Recall: 0.4054 F1 Score: 0.2582
# Running: rf_n_estimators 909, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 3, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8778 Precision: 0.2091 Recall: 0.3730 F1 Score: 0.2680
# Running: rf_n_estimators 939, rf_criterion gini, rf_max_depth 7, rf_min_samples_split 29, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8379 Precision: 0.1792 Recall: 0.4757 F1 Score: 0.2604
# Running: rf_n_estimators 981, rf_criterion log_loss, rf_max_depth 71, rf_min_samples_split 24, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9257 Precision: 0.2609 Recall: 0.1297 F1 Score: 0.1733
# Running: rf_n_estimators 70, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 3, rf_min_samples_leaf 21,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8923 Precision: 0.2288 Recall: 0.3351 F1 Score: 0.2719
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 9, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8797 Precision: 0.2165 Recall: 0.3838 F1 Score: 0.2768
# Running: rf_n_estimators 395, rf_criterion gini, rf_max_depth 43, rf_min_samples_split 22, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9193 Precision: 0.2419 Recall: 0.1622 F1 Score: 0.1942
# Running: rf_n_estimators 376, rf_criterion log_loss, rf_max_depth 10, rf_min_samples_split 9, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8966 Precision: 0.2320 Recall: 0.3135 F1 Score: 0.2667
# Running: rf_n_estimators 667, rf_criterion log_loss, rf_max_depth 11, rf_min_samples_split 28, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8985 Precision: 0.2419 Recall: 0.3243 F1 Score: 0.2771
# Running: rf_n_estimators 154, rf_criterion log_loss, rf_max_depth 10, rf_min_samples_split 4, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8875 Precision: 0.2168 Recall: 0.3351 F1 Score: 0.2633
# Running: rf_n_estimators 941, rf_criterion entropy, rf_max_depth 10, rf_min_samples_split 3, rf_min_samples_leaf 9,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8923 Precision: 0.2162 Recall: 0.3027 F1 Score: 0.2523
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8907 Precision: 0.2286 Recall: 0.3459 F1 Score: 0.2753
# Best f1: -0.2792607802874743
# Best params: [598, 'gini', 9, 29, 8]

# %% [markdown]
# 20000 epochs + OrdinalEncoder
#
# Accuracy: 0.7455 Precision: 0.1411 Recall: 0.6378 F1 Score: 0.2311

# %% [markdown]
# 2000 epochs + OrdinalEncoder
#
# Accuracy: 0.8100 Precision: 0.1607 Recall: 0.5135 F1 Score: 0.2448

# %% [markdown]
# Best F1

# %% [markdown]
# 64, 'entropy', 8, 30, 16
