# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
)
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from skopt import gp_minimize
from collections import Counter

# %%
# Load data
df = pd.read_csv(
    "../../data/Angoss Knowledge Seeker - carclaims.txt/carclaims_original.csv"
)
# Drop row with missing data
df.drop(df[df["DayOfWeekClaimed"] == "0"].index, inplace=True)
# Drop ID column
df.drop(columns="PolicyNumber", inplace=True)

# Train-test split
carclaims_train, carclaims_test = train_test_split(df, test_size=0.2, random_state=141)

# %%
space = [
    Integer(64, 1024, name="rf_n_estimators"),
    Categorical(["gini", "entropy", "log_loss"], name="rf_criterion"),
    Integer(5, 100, name="rf_max_depth"),
    Integer(2, 30, name="rf_min_samples_split"),
    Integer(1, 30, name="rf_min_samples_leaf"),
]

@use_named_args(space)
def train_and_predict(
    rf_n_estimators,
    rf_criterion,
    rf_max_depth,
    rf_min_samples_split,
    rf_min_samples_leaf,
):
    
    print(f'Running: rf_n_estimators {rf_n_estimators}, rf_criterion {rf_criterion}, rf_max_depth {rf_max_depth}, rf_min_samples_split {rf_min_samples_split}, rf_min_samples_leaf {rf_min_samples_leaf},')
   
    # X y split
    X_train = carclaims_train.drop('FraudFound', axis=1)
    y_train = carclaims_train['FraudFound']

    X_test = carclaims_test.drop('FraudFound', axis=1)
    y_test = carclaims_test['FraudFound']

    # Encode target variable
    y_train = y_train.map({'Yes': 1, 'No': 0})
    y_test = y_test.map({'Yes': 1, 'No': 0})

    y_train = y_train.astype(int)
    y_test = y_test.astype(int)

    # Lebel Encode features
    column_labels = {
        'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        'DayOfWeek': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
        'DayOfWeekClaimed': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
        'MonthClaimed': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        'AgeOfPolicyHolder': ['16 to 17', '18 to 20', '21 to 25', '26 to 30', '31 to 35', '36 to 40', '41 to 50', '51 to 65', 'over 65'],
        'NumberOfSuppliments': ['none', '1 to 2', '3 to 5', 'more than 5'],
        'AddressChange-Claim': ['no change', 'under 6 months', '1 year', '2 to 3 years', '4 to 8 years'],
        'NumberOfCars': ['1 vehicle', '2 vehicles', '3 to 4', '5 to 8', 'more than 8'],
        'VehiclePrice': ['less than 20,000', '20,000 to 29,000', '30,000 to 39,000', '40,000 to 59,000', '60,000 to 69,000', 'more than 69,000'],
        'Days:Policy-Accident': ['none', '1 to 7', '15 to 30', '8 to 15', 'more than 30'],
        'Days:Policy-Claim': ['15 to 30', '8 to 15', 'more than 30'],
        'PastNumberOfClaims': ['none', '1', '2 to 4', 'more than 4'],
        'AgeOfVehicle': ['new', '2 years', '3 years', '4 years', '5 years', '6 years', '7 years', 'more than 7'],
        'Make': ['Accura', 'BMW', 'Chevrolet', 'Dodge', 'Ferrari', 'Ford', 'Honda', 'Jaguar', 'Lexus', 'Mazda', 'Mecedes', 'Mercury', 'Nisson', 'Pontiac', 'Porche', 'Saab', 'Saturn', 'Toyota', 'VW']
    
        }

    for column, labels in column_labels.items():
        oe = OrdinalEncoder(categories=[labels], handle_unknown='error')
        X_train[column] = oe.fit_transform(X_train[[column]])
        X_test[column] = oe.transform(X_test[[column]])

    # one hot encode
    columns_one_hot = {
        'AccidentArea': ['Rural', 'Urban'],
        'Sex': ['Female', 'Male'],
        'MaritalStatus': ['Divorced', 'Married', 'Single', 'Widow'],
        'PoliceReportFiled': ['No', 'Yes'],
        'WitnessPresent': ['No', 'Yes'],
        'AgentType': ['External', 'Internal'],
        'BasePolicy': ['All Perils', 'Collision', 'Liability'],
        'Fault': ['Policy Holder', 'Third Party'],
        'PolicyType': ['Sedan - All Perils', 'Sedan - Collision', 'Sedan - Liability','Sport - All Perils', 'Sport - Collision', 'Sport - Liability', 'Utility - All Perils', 'Utility - Collision', 'Utility - Liability'],
        'VehicleCategory': ['Sedan', 'Sport', 'Utility'],
        
    }

    for column, labels in columns_one_hot.items():
        ohe = OneHotEncoder(sparse_output=False, categories=[labels], drop='first', handle_unknown='error')
        encoded_nominal = ohe.fit_transform(X_train[[column]])
        X_train = pd.concat([X_train, pd.DataFrame(encoded_nominal, columns=ohe.get_feature_names_out([column]), index=X_train.index)], axis=1)

        encoded_nominal = ohe.transform(X_test[[column]])
        X_test = pd.concat([X_test, pd.DataFrame(encoded_nominal, columns=ohe.get_feature_names_out([column]), index=X_test.index)], axis=1)

    X_test.drop(columns=columns_one_hot.keys(), axis=1, inplace=True)
    X_train.drop(columns=columns_one_hot.keys(), axis=1, inplace=True)
    
    print('Original dataset shape %s' % Counter(y_train))    
    sm = SMOTE(random_state=42)
    X_train_balanced, y_train_balanced = sm.fit_resample(X_train, y_train)
    print('Balanced dataset shape %s' % Counter(y_train_balanced))

    rf_classifier = RandomForestClassifier(
        n_estimators=rf_n_estimators,
        criterion=rf_criterion,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        random_state=141,
    )
    rf_classifier.fit(X_train_balanced, y_train_balanced)

    y_pred = rf_classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.4f} Precision: {precision:.4f} Recall: {recall:.4f} F1 Score: {f1:.4f}")
    return -f1
    
res_gp = gp_minimize(train_and_predict, space, n_calls=100, random_state=141)

print(f'Best f1: {res_gp.fun}')
print(f'Best params: {res_gp.x}')
# Out:
# Running: rf_n_estimators 406, rf_criterion gini, rf_max_depth 52, rf_min_samples_split 26, rf_min_samples_leaf 17,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9270 Precision: 0.2368 Recall: 0.0973 F1 Score: 0.1379
# Running: rf_n_estimators 830, rf_criterion entropy, rf_max_depth 85, rf_min_samples_split 26, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9313 Precision: 0.2712 Recall: 0.0865 F1 Score: 0.1311
# Running: rf_n_estimators 904, rf_criterion entropy, rf_max_depth 93, rf_min_samples_split 12, rf_min_samples_leaf 13,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9319 Precision: 0.2340 Recall: 0.0595 F1 Score: 0.0948
# Running: rf_n_estimators 763, rf_criterion gini, rf_max_depth 75, rf_min_samples_split 10, rf_min_samples_leaf 14,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9277 Precision: 0.2361 Recall: 0.0919 F1 Score: 0.1323
# Running: rf_n_estimators 375, rf_criterion gini, rf_max_depth 82, rf_min_samples_split 6, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9296 Precision: 0.2333 Recall: 0.0757 F1 Score: 0.1143
# Running: rf_n_estimators 350, rf_criterion entropy, rf_max_depth 57, rf_min_samples_split 23, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9319 Precision: 0.2881 Recall: 0.0919 F1 Score: 0.1393
# Running: rf_n_estimators 173, rf_criterion entropy, rf_max_depth 84, rf_min_samples_split 19, rf_min_samples_leaf 7,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9342 Precision: 0.2353 Recall: 0.0432 F1 Score: 0.0731
# Running: rf_n_estimators 489, rf_criterion gini, rf_max_depth 39, rf_min_samples_split 23, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9257 Precision: 0.2105 Recall: 0.0865 F1 Score: 0.1226
# Running: rf_n_estimators 172, rf_criterion entropy, rf_max_depth 80, rf_min_samples_split 14, rf_min_samples_leaf 7,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9339 Precision: 0.2121 Recall: 0.0378 F1 Score: 0.0642
# Running: rf_n_estimators 293, rf_criterion gini, rf_max_depth 37, rf_min_samples_split 18, rf_min_samples_leaf 28,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.2119 Recall: 0.1351 F1 Score: 0.1650
# Running: rf_n_estimators 123, rf_criterion log_loss, rf_max_depth 59, rf_min_samples_split 4, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9248 Precision: 0.2169 Recall: 0.0973 F1 Score: 0.1343
# Running: rf_n_estimators 774, rf_criterion gini, rf_max_depth 70, rf_min_samples_split 4, rf_min_samples_leaf 27,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.1964 Recall: 0.1189 F1 Score: 0.1481
# Running: rf_n_estimators 834, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 21, rf_min_samples_leaf 29,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7792 Precision: 0.1527 Recall: 0.5892 F1 Score: 0.2425
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 100, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.2213 Recall: 0.1459 F1 Score: 0.1759
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 100, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9241 Precision: 0.2184 Recall: 0.1027 F1 Score: 0.1397
# Running: rf_n_estimators 1024, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7815 Precision: 0.1522 Recall: 0.5784 F1 Score: 0.2410
# Running: rf_n_estimators 221, rf_criterion log_loss, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7847 Precision: 0.1534 Recall: 0.5730 F1 Score: 0.2420
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 29,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7909 Precision: 0.1567 Recall: 0.5676 F1 Score: 0.2456
# Running: rf_n_estimators 1024, rf_criterion log_loss, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 25,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7827 Precision: 0.1521 Recall: 0.5730 F1 Score: 0.2404
# Running: rf_n_estimators 96, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 17, rf_min_samples_leaf 24,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7837 Precision: 0.1547 Recall: 0.5838 F1 Score: 0.2446
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 23,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7879 Precision: 0.1567 Recall: 0.5784 F1 Score: 0.2465
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 2, rf_min_samples_leaf 14,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7896 Precision: 0.1558 Recall: 0.5676 F1 Score: 0.2445
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 18,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7892 Precision: 0.1566 Recall: 0.5730 F1 Score: 0.2459
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 17, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9189 Precision: 0.2124 Recall: 0.1297 F1 Score: 0.1611
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 29, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.2213 Recall: 0.1459 F1 Score: 0.1759
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7889 Precision: 0.1584 Recall: 0.5838 F1 Score: 0.2491
# Running: rf_n_estimators 968, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7815 Precision: 0.1542 Recall: 0.5892 F1 Score: 0.2444
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 30, rf_min_samples_leaf 13,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7896 Precision: 0.1568 Recall: 0.5730 F1 Score: 0.2462
# Running: rf_n_estimators 1024, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8859 Precision: 0.2091 Recall: 0.3243 F1 Score: 0.2542
# Running: rf_n_estimators 1024, rf_criterion entropy, rf_max_depth 12, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8972 Precision: 0.2000 Recall: 0.2378 F1 Score: 0.2173
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8787 Precision: 0.2110 Recall: 0.3730 F1 Score: 0.2695
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8752 Precision: 0.1988 Recall: 0.3568 F1 Score: 0.2553
# Running: rf_n_estimators 490, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8755 Precision: 0.2065 Recall: 0.3784 F1 Score: 0.2672
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8898 Precision: 0.1937 Recall: 0.2649 F1 Score: 0.2237
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 30, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8700 Precision: 0.2158 Recall: 0.4432 F1 Score: 0.2903
# Running: rf_n_estimators 214, rf_criterion entropy, rf_max_depth 25, rf_min_samples_split 12, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9371 Precision: 0.2632 Recall: 0.0270 F1 Score: 0.0490
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 30, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8651 Precision: 0.2031 Recall: 0.4270 F1 Score: 0.2753
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 9, rf_min_samples_split 30, rf_min_samples_leaf 19,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8765 Precision: 0.1918 Recall: 0.3297 F1 Score: 0.2425
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 6, rf_min_samples_split 30, rf_min_samples_leaf 15,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8149 Precision: 0.1695 Recall: 0.5351 F1 Score: 0.2575
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 10, rf_min_samples_split 30, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8846 Precision: 0.2000 Recall: 0.3081 F1 Score: 0.2426
# Running: rf_n_estimators 901, rf_criterion entropy, rf_max_depth 65, rf_min_samples_split 23, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9361 Precision: 0.2273 Recall: 0.0270 F1 Score: 0.0483
# Running: rf_n_estimators 64, rf_criterion log_loss, rf_max_depth 8, rf_min_samples_split 22, rf_min_samples_leaf 22,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8599 Precision: 0.1905 Recall: 0.4108 F1 Score: 0.2603
# Running: rf_n_estimators 1024, rf_criterion log_loss, rf_max_depth 100, rf_min_samples_split 25, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9358 Precision: 0.2400 Recall: 0.0324 F1 Score: 0.0571
# Running: rf_n_estimators 335, rf_criterion entropy, rf_max_depth 46, rf_min_samples_split 10, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9228 Precision: 0.2268 Recall: 0.1189 F1 Score: 0.1560
# Running: rf_n_estimators 914, rf_criterion log_loss, rf_max_depth 8, rf_min_samples_split 16, rf_min_samples_leaf 8,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8628 Precision: 0.1901 Recall: 0.3946 F1 Score: 0.2566
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 3, rf_min_samples_leaf 13,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8482 Precision: 0.1931 Recall: 0.4811 F1 Score: 0.2755
# Running: rf_n_estimators 1024, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 14,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8470 Precision: 0.1860 Recall: 0.4595 F1 Score: 0.2648
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 89, rf_min_samples_split 5, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9180 Precision: 0.2213 Recall: 0.1459 F1 Score: 0.1759
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8492 Precision: 0.1957 Recall: 0.4865 F1 Score: 0.2791
# Running: rf_n_estimators 919, rf_criterion gini, rf_max_depth 79, rf_min_samples_split 30, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9167 Precision: 0.2143 Recall: 0.1459 F1 Score: 0.1736
# Running: rf_n_estimators 220, rf_criterion entropy, rf_max_depth 48, rf_min_samples_split 24, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9351 Precision: 0.2000 Recall: 0.0270 F1 Score: 0.0476
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 28, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8495 Precision: 0.1934 Recall: 0.4757 F1 Score: 0.2750
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 26, rf_min_samples_leaf 4,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8671 Precision: 0.2000 Recall: 0.4054 F1 Score: 0.2679
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 13,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8482 Precision: 0.1931 Recall: 0.4811 F1 Score: 0.2755
# Running: rf_n_estimators 391, rf_criterion entropy, rf_max_depth 32, rf_min_samples_split 6, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9225 Precision: 0.2245 Recall: 0.1189 F1 Score: 0.1555
# Running: rf_n_estimators 80, rf_criterion entropy, rf_max_depth 15, rf_min_samples_split 15, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9270 Precision: 0.2297 Recall: 0.0919 F1 Score: 0.1313
# Running: rf_n_estimators 71, rf_criterion gini, rf_max_depth 6, rf_min_samples_split 8, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8291 Precision: 0.1774 Recall: 0.5081 F1 Score: 0.2629
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 2, rf_min_samples_leaf 16,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8700 Precision: 0.2158 Recall: 0.4432 F1 Score: 0.2903
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 33, rf_min_samples_split 26, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9329 Precision: 0.2105 Recall: 0.0432 F1 Score: 0.0717
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 26, rf_min_samples_leaf 21,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8615 Precision: 0.1881 Recall: 0.3946 F1 Score: 0.2548
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8508 Precision: 0.1938 Recall: 0.4703 F1 Score: 0.2744
# Running: rf_n_estimators 571, rf_criterion gini, rf_max_depth 22, rf_min_samples_split 4, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9170 Precision: 0.2114 Recall: 0.1405 F1 Score: 0.1688
# Running: rf_n_estimators 825, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 5, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8632 Precision: 0.1906 Recall: 0.3946 F1 Score: 0.2570
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 264, rf_criterion entropy, rf_max_depth 74, rf_min_samples_split 22, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9235 Precision: 0.2316 Recall: 0.1189 F1 Score: 0.1571
# Running: rf_n_estimators 744, rf_criterion gini, rf_max_depth 53, rf_min_samples_split 28, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9167 Precision: 0.2097 Recall: 0.1405 F1 Score: 0.1683
# Running: rf_n_estimators 958, rf_criterion entropy, rf_max_depth 5, rf_min_samples_split 4, rf_min_samples_leaf 2,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7779 Precision: 0.1518 Recall: 0.5892 F1 Score: 0.2414
# Running: rf_n_estimators 197, rf_criterion gini, rf_max_depth 58, rf_min_samples_split 24, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9358 Precision: 0.2593 Recall: 0.0378 F1 Score: 0.0660
# Running: rf_n_estimators 64, rf_criterion log_loss, rf_max_depth 7, rf_min_samples_split 4, rf_min_samples_leaf 4,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8473 Precision: 0.1836 Recall: 0.4486 F1 Score: 0.2606
# Running: rf_n_estimators 1021, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 6, rf_min_samples_leaf 9,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8651 Precision: 0.1969 Recall: 0.4054 F1 Score: 0.2650
# Running: rf_n_estimators 64, rf_criterion gini, rf_max_depth 8, rf_min_samples_split 13, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8567 Precision: 0.1811 Recall: 0.3946 F1 Score: 0.2483
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 4, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 124, rf_criterion log_loss, rf_max_depth 8, rf_min_samples_split 16, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8589 Precision: 0.1995 Recall: 0.4486 F1 Score: 0.2762
# Running: rf_n_estimators 748, rf_criterion gini, rf_max_depth 95, rf_min_samples_split 23, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9170 Precision: 0.2114 Recall: 0.1405 F1 Score: 0.1688
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 2, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8700 Precision: 0.2033 Recall: 0.4000 F1 Score: 0.2696
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 8, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 6, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 414, rf_criterion entropy, rf_max_depth 65, rf_min_samples_split 20, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9238 Precision: 0.2340 Recall: 0.1189 F1 Score: 0.1577
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 7, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 24, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8486 Precision: 0.1935 Recall: 0.4811 F1 Score: 0.2760
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 22, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 533, rf_criterion log_loss, rf_max_depth 14, rf_min_samples_split 28, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9092 Precision: 0.2013 Recall: 0.1730 F1 Score: 0.1860
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 6, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8713 Precision: 0.2039 Recall: 0.3946 F1 Score: 0.2689
# Running: rf_n_estimators 439, rf_criterion log_loss, rf_max_depth 44, rf_min_samples_split 4, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9232 Precision: 0.2292 Recall: 0.1189 F1 Score: 0.1566
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 3, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8505 Precision: 0.1987 Recall: 0.4919 F1 Score: 0.2830
# Running: rf_n_estimators 145, rf_criterion entropy, rf_max_depth 83, rf_min_samples_split 19, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9241 Precision: 0.2247 Recall: 0.1081 F1 Score: 0.1460
# Running: rf_n_estimators 389, rf_criterion entropy, rf_max_depth 26, rf_min_samples_split 24, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9225 Precision: 0.2245 Recall: 0.1189 F1 Score: 0.1555
# Running: rf_n_estimators 632, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 27, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8593 Precision: 0.1895 Recall: 0.4108 F1 Score: 0.2594
# Running: rf_n_estimators 631, rf_criterion gini, rf_max_depth 91, rf_min_samples_split 23, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9355 Precision: 0.2500 Recall: 0.0378 F1 Score: 0.0657
# Running: rf_n_estimators 72, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8450 Precision: 0.1849 Recall: 0.4649 F1 Score: 0.2646
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 30, rf_min_samples_leaf 11,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8499 Precision: 0.1938 Recall: 0.4757 F1 Score: 0.2754
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 25, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8466 Precision: 0.1897 Recall: 0.4757 F1 Score: 0.2712
# Running: rf_n_estimators 915, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 2, rf_min_samples_leaf 12,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8476 Precision: 0.1854 Recall: 0.4541 F1 Score: 0.2633
# Running: rf_n_estimators 64, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 4, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8508 Precision: 0.1938 Recall: 0.4703 F1 Score: 0.2744
# Running: rf_n_estimators 729, rf_criterion gini, rf_max_depth 5, rf_min_samples_split 10, rf_min_samples_leaf 1,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.7818 Precision: 0.1544 Recall: 0.5892 F1 Score: 0.2447
# Running: rf_n_estimators 108, rf_criterion entropy, rf_max_depth 7, rf_min_samples_split 19, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8444 Precision: 0.1868 Recall: 0.4757 F1 Score: 0.2683
# Running: rf_n_estimators 847, rf_criterion entropy, rf_max_depth 40, rf_min_samples_split 5, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.9225 Precision: 0.2300 Recall: 0.1243 F1 Score: 0.1614
# Running: rf_n_estimators 78, rf_criterion log_loss, rf_max_depth 7, rf_min_samples_split 26, rf_min_samples_leaf 10,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8418 Precision: 0.1811 Recall: 0.4649 F1 Score: 0.2606
# Running: rf_n_estimators 1019, rf_criterion entropy, rf_max_depth 8, rf_min_samples_split 16, rf_min_samples_leaf 19,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8635 Precision: 0.1943 Recall: 0.4054 F1 Score: 0.2627
# Running: rf_n_estimators 989, rf_criterion log_loss, rf_max_depth 7, rf_min_samples_split 21, rf_min_samples_leaf 30,
# Original dataset shape Counter({0: 11597, 1: 738})
# Balanced dataset shape Counter({0: 11597, 1: 11597})
# Accuracy: 0.8463 Precision: 0.1810 Recall: 0.4432 F1 Score: 0.2571
# Best f1: -0.2902654867256637
# Best params: [64, 'entropy', 8, 30, 16]

# %% [markdown]
# 20000 epochs + OrdinalEncoder
#
# Accuracy: 0.7455 Precision: 0.1411 Recall: 0.6378 F1 Score: 0.2311

# %% [markdown]
# 2000 epochs + OrdinalEncoder
#
# Accuracy: 0.8100 Precision: 0.1607 Recall: 0.5135 F1 Score: 0.2448

# %% [markdown]
# Best F1

# %% [markdown]
# 64, 'entropy', 8, 30, 16
